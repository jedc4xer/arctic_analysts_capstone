# %%
import arima_model as arm
import data_getter as data_con
import importlib
import pandas as pd

importlib.reload(arm)

targets = ['MedianIncome', 'MedianHousePrice', 'AverageRate','AveragePoints','NewBuildings','NewUnits']
target = 'MedianIncome'
age_range = '25-44'
target_fips = '34001'



all_df = data_con.run_queries()
master_table = data_con.join_tables(all_df)

prediction_dataframes = []
age_ranges = master_table.AgeGroup.unique().tolist()
age_ranges = [_ for _ in age_ranges if str(_) != 'nan']
all_fips = master_table.FIPS.unique().tolist()
total = len(all_fips) * len(age_ranges)

cntr = 0
for i, age_range in enumerate(age_ranges):
    for ii, target_fips in enumerate(all_fips):
        params = [target_fips, age_range]
        target = 'MedianIncome'
        try:
            graph_ready, export_ready = arm.dispatcher(master_table, target, params)
        except Exception as E:
            print(f'Failure: {E}, params: {params}')
            cntr += 1
            continue
        export_ready['AgeGroup'] = age_range
        prediction_dataframes.append(export_ready)
        cntr += 1
        print(f'{cntr} of {total} completed')
# Out:
# 5607
# 5607
# 5607
# 20727
# Column: MedianIncome | ADF Statistic: -1.9409253794967736 | P-Value: 0.3130600699176723
# In the best result. Current Iteration: 1, current_col: diff_1
# Column: diff_1 | ADF Statistic: -5.954910972439216 | P-Value: 2.1044107953091916e-07
# Column: diff_2 | ADF Statistic: -5.432380898083569 | P-Value: 2.895222693154003e-06
#
# ###############################################
#
# Best Result: Column: diff_1 | ADF Statistic: -5.432380898083569
# P-Value: 2.895222693154003e-06 | Passed? True | Num Diffs: 1
#
# ###############################################
#
# (15, 6)
# Best Num Differences: 1
# ARIMA(0, 1, 0) RMSE=7690.081
# ARIMA(0, 1, 1) RMSE=4609.790
# Input contains NaN, infinity or a value too large for dtype('float64').
# Input contains NaN, infinity or a value too large for dtype('float64').
# ARIMA(0, 1, 4) RMSE=4296.650
# ARIMA(1, 1, 1) RMSE=3915.015
# Schur decomposition solver error.
# Schur decomposition solver error.
# ARIMA(2, 1, 0) RMSE=3702.103
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# LU decomposition error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# LU decomposition error.
# LU decomposition error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# LU decomposition error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Best ARIMA(2, 1, 0) RMSE=3702.103
# Run Completed. Dataframes Exported: "graph_ready", "export_ready"
# 1 of 105 completed
# Column: MedianIncome | ADF Statistic: 4.140170176639361 | P-Value: 1.0
# In the best result. Current Iteration: 1, current_col: diff_1
# Column: diff_1 | ADF Statistic: 0.9126391187009933 | P-Value: 0.9932530731907094
# In the best result. Current Iteration: 2, current_col: diff_2
# Column: diff_2 | ADF Statistic: -4.891766908288081 | P-Value: 3.6184340862273524e-05
#
# ###############################################
#
# Best Result: Column: diff_2 | ADF Statistic: -4.891766908288081
# P-Value: 3.6184340862273524e-05 | Passed? True | Num Diffs: 2
#
# ###############################################
#
# (15, 6)
# Best Num Differences: 2
# ARIMA(0, 2, 0) RMSE=18968.499
# ARIMA(0, 2, 1) RMSE=11220.932
# Input contains NaN, infinity or a value too large for dtype('float64').
# ARIMA(0, 2, 3) RMSE=10074.919
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# LU decomposition error.
# LU decomposition error.
# Schur decomposition solver error.
# LU decomposition error.
# LU decomposition error.
# Schur decomposition solver error.
# Best ARIMA(0, 2, 3) RMSE=10074.919
# Run Completed. Dataframes Exported: "graph_ready", "export_ready"
# 2 of 105 completed
# Column: MedianIncome | ADF Statistic: 1.5118163853864957 | P-Value: 0.997567349044605
# In the best result. Current Iteration: 1, current_col: diff_1
# Column: diff_1 | ADF Statistic: -6.3683795662213445 | P-Value: 2.378512543155409e-08
# Column: diff_2 | ADF Statistic: -3.3046134304587165 | P-Value: 0.014673509278079916
#
# ###############################################
#
# Best Result: Column: diff_1 | ADF Statistic: -3.3046134304587165
# P-Value: 0.014673509278079916 | Passed? True | Num Diffs: 1
#
# ###############################################
#
# (15, 6)
# Best Num Differences: 1
# ARIMA(0, 1, 0) RMSE=12081.356
# ARIMA(0, 1, 1) RMSE=6270.896
# Input contains NaN, infinity or a value too large for dtype('float64').
# Input contains NaN, infinity or a value too large for dtype('float64').
# Schur decomposition solver error.
# LU decomposition error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# ARIMA(3, 1, 1) RMSE=6250.924
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# LU decomposition error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Best ARIMA(3, 1, 1) RMSE=6250.924
# Run Completed. Dataframes Exported: "graph_ready", "export_ready"
# 3 of 105 completed
# Column: MedianIncome | ADF Statistic: -1.1918316547064411 | P-Value: 0.6770996203672889
# In the best result. Current Iteration: 1, current_col: diff_1
# Column: diff_1 | ADF Statistic: -1.5367391712150835 | P-Value: 0.5152650910296549
# In the best result. Current Iteration: 2, current_col: diff_2
# Column: diff_2 | ADF Statistic: -3.2021297086828877 | P-Value: 0.019861733807285276
#
# ###############################################
#
# Best Result: Column: diff_2 | ADF Statistic: -3.2021297086828877
# P-Value: 0.019861733807285276 | Passed? True | Num Diffs: 2
#
# ###############################################
#
# (15, 6)
# Best Num Differences: 2
# ARIMA(0, 2, 0) RMSE=19352.268
# ARIMA(0, 2, 1) RMSE=10791.993
# Input contains NaN, infinity or a value too large for dtype('float64').
# ARIMA(0, 2, 3) RMSE=8821.689
# ARIMA(0, 2, 4) RMSE=8613.435
# ARIMA(1, 2, 1) RMSE=7839.365
# Schur decomposition solver error.
# Schur decomposition solver error.
# LU decomposition error.
# Schur decomposition solver error.
# LU decomposition error.
# Schur decomposition solver error.
# LU decomposition error.
# Schur decomposition solver error.
# LU decomposition error.
# LU decomposition error.
# Schur decomposition solver error.
# Best ARIMA(1, 2, 1) RMSE=7839.365
# Run Completed. Dataframes Exported: "graph_ready", "export_ready"
# 4 of 105 completed
# Column: MedianIncome | ADF Statistic: -3.4660244514058514 | P-Value: 0.0089037540365283
# In the best result. Current Iteration: 1, current_col: diff_1
# Column: diff_1 | ADF Statistic: -4.796810948438295 | P-Value: 5.515506690743705e-05
# In the best result. Current Iteration: 2, current_col: diff_2
# Column: diff_2 | ADF Statistic: -5.028351055794531 | P-Value: 1.949757529033743e-05
#
# ###############################################
#
# Best Result: Column: diff_2 | ADF Statistic: -5.028351055794531
# P-Value: 1.949757529033743e-05 | Passed? True | Num Diffs: 2
#
# ###############################################
#
# (15, 6)
# Best Num Differences: 2
# ARIMA(0, 2, 0) RMSE=70890.106
# ARIMA(0, 2, 1) RMSE=38199.187
# Input contains NaN, infinity or a value too large for dtype('float64').
# ARIMA(0, 2, 3) RMSE=19418.811
# ARIMA(0, 2, 4) RMSE=15433.434
# Schur decomposition solver error.
# ARIMA(1, 2, 4) RMSE=15073.701
# Schur decomposition solver error.
# Schur decomposition solver error.
# LU decomposition error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Best ARIMA(1, 2, 4) RMSE=15073.701
# Run Completed. Dataframes Exported: "graph_ready", "export_ready"
# 5 of 105 completed
# Column: MedianIncome | ADF Statistic: -0.5706148480218463 | P-Value: 0.8774845923223276
# In the best result. Current Iteration: 1, current_col: diff_1
# Column: diff_1 | ADF Statistic: -4.749766732323693 | P-Value: 6.778760573247009e-05
# Column: diff_2 | ADF Statistic: -2.101285611267077 | P-Value: 0.24399796508960653
#
# ###############################################
#
# Best Result: Column: diff_1 | ADF Statistic: -2.101285611267077
# P-Value: 0.24399796508960653 | Passed? False | Num Diffs: 1
#
# ###############################################
#
# (15, 6)
# Best Num Differences: 1
# ARIMA(0, 1, 0) RMSE=12696.448
# Input contains NaN, infinity or a value too large for dtype('float64').
# Input contains NaN, infinity or a value too large for dtype('float64').
# ARIMA(0, 1, 4) RMSE=9840.782
# Schur decomposition solver error.
# Schur decomposition solver error.
# ARIMA(1, 1, 4) RMSE=9804.633
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# ARIMA(3, 1, 4) RMSE=9640.915
# ARIMA(4, 1, 1) RMSE=9633.341
# Schur decomposition solver error.
# Schur decomposition solver error.
# LU decomposition error.
# ARIMA(5, 1, 1) RMSE=8928.172
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Best ARIMA(5, 1, 1) RMSE=8928.172
# Run Completed. Dataframes Exported: "graph_ready", "export_ready"
# 6 of 105 completed
# Column: MedianIncome | ADF Statistic: -0.7976723829536262 | P-Value: 0.8198048315343138
# In the best result. Current Iteration: 1, current_col: diff_1
# Column: diff_1 | ADF Statistic: -0.8249128667924371 | P-Value: 0.811694354417692
# In the best result. Current Iteration: 2, current_col: diff_2
# Column: diff_2 | ADF Statistic: -5.160481022954245 | P-Value: 1.0581189426741736e-05
#
# ###############################################
#
# Best Result: Column: diff_2 | ADF Statistic: -5.160481022954245
# P-Value: 1.0581189426741736e-05 | Passed? True | Num Diffs: 2
#
# ###############################################
#
# (15, 6)
# Best Num Differences: 2
# ARIMA(0, 2, 0) RMSE=19343.984
# ARIMA(0, 2, 1) RMSE=12136.238
# Input contains NaN, infinity or a value too large for dtype('float64').
# ARIMA(0, 2, 3) RMSE=9508.211
# ARIMA(0, 2, 4) RMSE=7395.623
# Schur decomposition solver error.
# ARIMA(2, 2, 1) RMSE=6885.016
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# LU decomposition error.
# LU decomposition error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Best ARIMA(2, 2, 1) RMSE=6885.016
# Run Completed. Dataframes Exported: "graph_ready", "export_ready"
# 7 of 105 completed
# Column: MedianIncome | ADF Statistic: 0.04868891295172956 | P-Value: 0.9623781278126795
# In the best result. Current Iteration: 1, current_col: diff_1
# Column: diff_1 | ADF Statistic: -1.711927309316753 | P-Value: 0.4249778826352147
# In the best result. Current Iteration: 2, current_col: diff_2
# Column: diff_2 | ADF Statistic: -3.8015102431483374 | P-Value: 0.0028919009716821915
#
# ###############################################
#
# Best Result: Column: diff_2 | ADF Statistic: -3.8015102431483374
# P-Value: 0.0028919009716821915 | Passed? True | Num Diffs: 2
#
# ###############################################
#
# (15, 6)
# Best Num Differences: 2
# ARIMA(0, 2, 0) RMSE=54559.028
# ARIMA(0, 2, 1) RMSE=31843.154
# Input contains NaN, infinity or a value too large for dtype('float64').
# ARIMA(0, 2, 3) RMSE=12395.250
# ARIMA(0, 2, 4) RMSE=10263.604
# Schur decomposition solver error.
# LU decomposition error.
# Schur decomposition solver error.
# LU decomposition error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# LU decomposition error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Best ARIMA(0, 2, 4) RMSE=10263.604
# Run Completed. Dataframes Exported: "graph_ready", "export_ready"
# 8 of 105 completed
# Column: MedianIncome | ADF Statistic: 0.8418666721889113 | P-Value: 0.9922827816086828
# In the best result. Current Iteration: 1, current_col: diff_1
# Column: diff_1 | ADF Statistic: -1.1096841455714144 | P-Value: 0.71119456889757
# Column: diff_2 | ADF Statistic: -0.7851292240515099 | P-Value: 0.8234512663546476
#
# ###############################################
#
# Best Result: Column: diff_1 | ADF Statistic: -0.7851292240515099
# P-Value: 0.8234512663546476 | Passed? False | Num Diffs: 1
#
# ###############################################
#
# (15, 6)
# Best Num Differences: 1
# ARIMA(0, 1, 0) RMSE=3145.580
# ARIMA(0, 1, 1) RMSE=2955.973
# Input contains NaN, infinity or a value too large for dtype('float64').
# Input contains NaN, infinity or a value too large for dtype('float64').
# ARIMA(0, 1, 4) RMSE=2618.591
# Schur decomposition solver error.
# Schur decomposition solver error.
# ARIMA(1, 1, 4) RMSE=2379.753
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# ARIMA(3, 1, 4) RMSE=2144.311
# LU decomposition error.
# LU decomposition error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# LU decomposition error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Best ARIMA(3, 1, 4) RMSE=2144.311
# Schur decomposition solver error.
# Failure: local variable 'predicted_data' referenced before assignment, params: ['34017', '25-44']
# Column: MedianIncome | ADF Statistic: -2.367095263899219 | P-Value: 0.1512396656352472
# Column: diff_1 | ADF Statistic: -1.9504060097741043 | P-Value: 0.3087323754233808
# In the best result. Current Iteration: 2, current_col: diff_2
# Column: diff_2 | ADF Statistic: -2.6241310712809103 | P-Value: 0.08811171809548712
#
# ###############################################
#
# Best Result: Column: diff_2 | ADF Statistic: -2.6241310712809103
# P-Value: 0.08811171809548712 | Passed? False | Num Diffs: 2
#
# ###############################################
#
# (15, 6)
# Best Num Differences: 2
# ARIMA(0, 2, 0) RMSE=59670.639
# ARIMA(0, 2, 1) RMSE=33876.735
# Input contains NaN, infinity or a value too large for dtype('float64').
# ARIMA(0, 2, 4) RMSE=29322.825
# ARIMA(1, 2, 1) RMSE=26603.540
# Schur decomposition solver error.
# LU decomposition error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# LU decomposition error.
# Schur decomposition solver error.
# LU decomposition error.
# LU decomposition error.
# Schur decomposition solver error.
# LU decomposition error.
# Schur decomposition solver error.
# Best ARIMA(1, 2, 1) RMSE=26603.540
# Run Completed. Dataframes Exported: "graph_ready", "export_ready"
# 10 of 105 completed
# Column: MedianIncome | ADF Statistic: -13.780120207735079 | P-Value: 9.330234605263518e-26
# In the best result. Current Iteration: 1, current_col: diff_1
# Column: diff_1 | ADF Statistic: -14.168080747321234 | P-Value: 2.0257513508383062e-26
# Column: diff_2 | ADF Statistic: -5.877933319631211 | P-Value: 3.127390289090924e-07
#
# ###############################################
#
# Best Result: Column: diff_1 | ADF Statistic: -5.877933319631211
# P-Value: 3.127390289090924e-07 | Passed? True | Num Diffs: 1
#
# ###############################################
#
# (15, 6)
# Best Num Differences: 1
# ARIMA(0, 1, 0) RMSE=7936.405
# ARIMA(0, 1, 1) RMSE=4915.070
# Input contains NaN, infinity or a value too large for dtype('float64').
# Input contains NaN, infinity or a value too large for dtype('float64').
# ARIMA(0, 1, 4) RMSE=4589.789
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Best ARIMA(0, 1, 4) RMSE=4589.789
# Run Completed. Dataframes Exported: "graph_ready", "export_ready"
# 11 of 105 completed
# Column: MedianIncome | ADF Statistic: -0.6754760151054681 | P-Value: 0.8529999584449695
# Column: diff_1 | ADF Statistic: -0.0012918084805799018 | P-Value: 0.9584251239312973
# In the best result. Current Iteration: 2, current_col: diff_2
# Column: diff_2 | ADF Statistic: -2.4536907161271704 | P-Value: 0.12715215171621264
#
# ###############################################
#
# Best Result: Column: diff_2 | ADF Statistic: -2.4536907161271704
# P-Value: 0.12715215171621264 | Passed? False | Num Diffs: 2
#
# ###############################################
#
# (15, 6)
# Best Num Differences: 2
# ARIMA(0, 2, 0) RMSE=21684.340
# ARIMA(0, 2, 1) RMSE=12868.574
# Input contains NaN, infinity or a value too large for dtype('float64').
# ARIMA(0, 2, 3) RMSE=9486.032
# ARIMA(0, 2, 4) RMSE=8116.615
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# LU decomposition error.
# Schur decomposition solver error.
# Best ARIMA(0, 2, 4) RMSE=8116.615
# Run Completed. Dataframes Exported: "graph_ready", "export_ready"
# 12 of 105 completed
# Column: MedianIncome | ADF Statistic: 1.2616476883484915 | P-Value: 0.9963853231364761
# In the best result. Current Iteration: 1, current_col: diff_1
# Column: diff_1 | ADF Statistic: -0.21614719231416524 | P-Value: 0.9365693457619324
# In the best result. Current Iteration: 2, current_col: diff_2
# Column: diff_2 | ADF Statistic: -1.83893191010866 | P-Value: 0.3613114578693913
#
# ###############################################
#
# Best Result: Column: diff_2 | ADF Statistic: -1.83893191010866
# P-Value: 0.3613114578693913 | Passed? False | Num Diffs: 2
#
# ###############################################
#
# (15, 6)
# Best Num Differences: 2
# ARIMA(0, 2, 0) RMSE=26645.701
# ARIMA(0, 2, 1) RMSE=14482.507
# Input contains NaN, infinity or a value too large for dtype('float64').
# ARIMA(0, 2, 3) RMSE=8030.777
# ARIMA(0, 2, 4) RMSE=8004.763
# ARIMA(1, 2, 1) RMSE=6807.904
# Schur decomposition solver error.
# Schur decomposition solver error.
# LU decomposition error.
# Schur decomposition solver error.
# LU decomposition error.
# Schur decomposition solver error.
# LU decomposition error.
# LU decomposition error.
# Schur decomposition solver error.
# LU decomposition error.
# LU decomposition error.
# Schur decomposition solver error.
# Best ARIMA(1, 2, 1) RMSE=6807.904
# Run Completed. Dataframes Exported: "graph_ready", "export_ready"
# 13 of 105 completed
# Column: MedianIncome | ADF Statistic: -1.5978520606336388 | P-Value: 0.48467237129834895
# In the best result. Current Iteration: 1, current_col: diff_1
# Column: diff_1 | ADF Statistic: -4.28679032649102 | P-Value: 0.00046820066972814045
# In the best result. Current Iteration: 2, current_col: diff_2
# Column: diff_2 | ADF Statistic: -7.753291258524181 | P-Value: 9.88858039710039e-12
#
# ###############################################
#
# Best Result: Column: diff_2 | ADF Statistic: -7.753291258524181
# P-Value: 9.88858039710039e-12 | Passed? True | Num Diffs: 2
#
# ###############################################
#
# (15, 6)
# Best Num Differences: 2
# ARIMA(0, 2, 0) RMSE=56924.817
# ARIMA(0, 2, 1) RMSE=32539.069
# Input contains NaN, infinity or a value too large for dtype('float64').
# ARIMA(0, 2, 3) RMSE=18390.122
# ARIMA(0, 2, 4) RMSE=16659.555
# ARIMA(1, 2, 1) RMSE=14558.304
# Schur decomposition solver error.
# ARIMA(2, 2, 1) RMSE=14270.956
# Schur decomposition solver error.
# Schur decomposition solver error.
# LU decomposition error.
# LU decomposition error.
# Schur decomposition solver error.
# LU decomposition error.
# Schur decomposition solver error.
# LU decomposition error.
# LU decomposition error.
# Schur decomposition solver error.
# Best ARIMA(2, 2, 1) RMSE=14270.956
# Run Completed. Dataframes Exported: "graph_ready", "export_ready"
# 14 of 105 completed
# Column: MedianIncome | ADF Statistic: -0.9619727712099756 | P-Value: 0.7668800494890047
# Column: diff_1 | ADF Statistic: 2.351680303005057 | P-Value: 0.9989857245284791
# In the best result. Current Iteration: 2, current_col: diff_2
# Column: diff_2 | ADF Statistic: -3.380184487916032 | P-Value: 0.011653216865927534
#
# ###############################################
#
# Best Result: Column: diff_2 | ADF Statistic: -3.380184487916032
# P-Value: 0.011653216865927534 | Passed? True | Num Diffs: 2
#
# ###############################################
#
# (15, 6)
# Best Num Differences: 2
# ARIMA(0, 2, 0) RMSE=20758.289
# ARIMA(0, 2, 1) RMSE=11851.513
# Input contains NaN, infinity or a value too large for dtype('float64').
# ARIMA(0, 2, 3) RMSE=7754.610
# ARIMA(0, 2, 4) RMSE=5114.239
# Schur decomposition solver error.
# ARIMA(1, 2, 4) RMSE=4765.480
# Schur decomposition solver error.
# LU decomposition error.
# Schur decomposition solver error.
# LU decomposition error.
# Schur decomposition solver error.
# LU decomposition error.
# Schur decomposition solver error.
# LU decomposition error.
# Schur decomposition solver error.
# Best ARIMA(1, 2, 4) RMSE=4765.480
# Run Completed. Dataframes Exported: "graph_ready", "export_ready"
# 15 of 105 completed
# Column: MedianIncome | ADF Statistic: 1.0727332207863352 | P-Value: 0.9949770600450931
# In the best result. Current Iteration: 1, current_col: diff_1
# Column: diff_1 | ADF Statistic: -4.850106484742792 | P-Value: 4.357225282449881e-05
# Column: diff_2 | ADF Statistic: -3.1595722332731855 | P-Value: 0.022447333947466917
#
# ###############################################
#
# Best Result: Column: diff_1 | ADF Statistic: -3.1595722332731855
# P-Value: 0.022447333947466917 | Passed? True | Num Diffs: 1
#
# ###############################################
#
# (15, 6)
# Best Num Differences: 1
# ARIMA(0, 1, 0) RMSE=10863.831
# ARIMA(0, 1, 1) RMSE=8329.222
# Input contains NaN, infinity or a value too large for dtype('float64').
# Input contains NaN, infinity or a value too large for dtype('float64').
# ARIMA(1, 1, 0) RMSE=8106.582
# Schur decomposition solver error.
# Schur decomposition solver error.
# ARIMA(2, 1, 0) RMSE=7565.260
# Schur decomposition solver error.
# Schur decomposition solver error.
# ARIMA(3, 1, 0) RMSE=7384.862
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# LU decomposition error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Best ARIMA(3, 1, 0) RMSE=7384.862
# Run Completed. Dataframes Exported: "graph_ready", "export_ready"
# 16 of 105 completed
# Column: MedianIncome | ADF Statistic: -3.8722493149662065 | P-Value: 0.0022488392795669216
# In the best result. Current Iteration: 1, current_col: diff_1
# Column: diff_1 | ADF Statistic: -5.814833026137681 | P-Value: 4.316719311883993e-07
# Column: diff_2 | ADF Statistic: -4.234587326056322 | P-Value: 0.0005754891482493164
#
# ###############################################
#
# Best Result: Column: diff_1 | ADF Statistic: -4.234587326056322
# P-Value: 0.0005754891482493164 | Passed? True | Num Diffs: 1
#
# ###############################################
#
# (15, 6)
# Best Num Differences: 1
# ARIMA(0, 1, 0) RMSE=15095.149
# ARIMA(0, 1, 1) RMSE=10006.656
# Input contains NaN, infinity or a value too large for dtype('float64').
# Input contains NaN, infinity or a value too large for dtype('float64').
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# LU decomposition error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Best ARIMA(0, 1, 1) RMSE=10006.656
# Run Completed. Dataframes Exported: "graph_ready", "export_ready"
# 17 of 105 completed
# Column: MedianIncome | ADF Statistic: -3.148528243045391 | P-Value: 0.02316416918410347
# Column: diff_1 | ADF Statistic: -2.1643082002079526 | P-Value: 0.21945351513544586
# Column: diff_2 | ADF Statistic: -2.7481522781773813 | P-Value: 0.06606997964469986
#
# ###############################################
#
# local variable 'best_col' referenced before assignment
# Failure: local variable 'predicted_data' referenced before assignment, params: ['34035', '25-44']
# Column: MedianIncome | ADF Statistic: -0.4607240788249118 | P-Value: 0.8994557449073692
# In the best result. Current Iteration: 1, current_col: diff_1
# Column: diff_1 | ADF Statistic: -3.1928809329754446 | P-Value: 0.020400474629081355
# In the best result. Current Iteration: 2, current_col: diff_2
# Column: diff_2 | ADF Statistic: -3.291564764855504 | P-Value: 0.015259766049343067
#
# ###############################################
#
# Best Result: Column: diff_2 | ADF Statistic: -3.291564764855504
# P-Value: 0.015259766049343067 | Passed? True | Num Diffs: 2
#
# ###############################################
#
# (15, 6)
# Best Num Differences: 2
# ARIMA(0, 2, 0) RMSE=46846.228
# ARIMA(0, 2, 1) RMSE=27498.828
# Input contains NaN, infinity or a value too large for dtype('float64').
# ARIMA(0, 2, 3) RMSE=19306.791
# ARIMA(0, 2, 4) RMSE=18999.008
# Schur decomposition solver error.
# ARIMA(2, 2, 1) RMSE=16092.383
# Schur decomposition solver error.
# LU decomposition error.
# Schur decomposition solver error.
# LU decomposition error.
# LU decomposition error.
# Schur decomposition solver error.
# LU decomposition error.
# LU decomposition error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Best ARIMA(2, 2, 1) RMSE=16092.383
# Run Completed. Dataframes Exported: "graph_ready", "export_ready"
# 19 of 105 completed
# Column: MedianIncome | ADF Statistic: -2.4040272015286988 | P-Value: 0.14060298556789513
# In the best result. Current Iteration: 1, current_col: diff_1
# Column: diff_1 | ADF Statistic: -2.5333193171883996 | P-Value: 0.10757638609418757
# In the best result. Current Iteration: 2, current_col: diff_2
# Column: diff_2 | ADF Statistic: -2.533478922788435 | P-Value: 0.10753955220242045
#
# ###############################################
#
# Best Result: Column: diff_2 | ADF Statistic: -2.533478922788435
# P-Value: 0.10753955220242045 | Passed? False | Num Diffs: 2
#
# ###############################################
#
# (15, 6)
# Best Num Differences: 2
# ARIMA(0, 2, 0) RMSE=20279.419
# ARIMA(0, 2, 1) RMSE=15123.873
# Input contains NaN, infinity or a value too large for dtype('float64').
# ARIMA(0, 2, 3) RMSE=14093.532
# ARIMA(1, 2, 1) RMSE=13463.277
# Schur decomposition solver error.
# Schur decomposition solver error.
# ARIMA(2, 2, 3) RMSE=13263.779
# Schur decomposition solver error.
# ARIMA(3, 2, 3) RMSE=13196.324
# LU decomposition error.
# Schur decomposition solver error.
# LU decomposition error.
# Schur decomposition solver error.
# ARIMA(5, 2, 3) RMSE=12325.093
# LU decomposition error.
# Schur decomposition solver error.
# Best ARIMA(5, 2, 3) RMSE=12325.093
# Run Completed. Dataframes Exported: "graph_ready", "export_ready"
# 20 of 105 completed
# Column: MedianIncome | ADF Statistic: -2.2387738112225275 | P-Value: 0.19247486144330256
# Column: diff_1 | ADF Statistic: 0.8211160857632266 | P-Value: 0.9919694871294168
# In the best result. Current Iteration: 2, current_col: diff_2
# Column: diff_2 | ADF Statistic: -11.945566955748687 | P-Value: 4.438700537678076e-22
#
# ###############################################
#
# Best Result: Column: diff_2 | ADF Statistic: -11.945566955748687
# P-Value: 4.438700537678076e-22 | Passed? True | Num Diffs: 2
#
# ###############################################
#
# (15, 6)
# Best Num Differences: 2
# ARIMA(0, 2, 0) RMSE=67655.543
# ARIMA(0, 2, 1) RMSE=37325.502
# Input contains NaN, infinity or a value too large for dtype('float64').
# ARIMA(0, 2, 3) RMSE=16655.569
# ARIMA(0, 2, 4) RMSE=15081.868
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# LU decomposition error.
# Schur decomposition solver error.
# LU decomposition error.
# Schur decomposition solver error.
# Best ARIMA(0, 2, 4) RMSE=15081.868
# Run Completed. Dataframes Exported: "graph_ready", "export_ready"
# 21 of 105 completed
# Column: MedianIncome | ADF Statistic: 0.4668611211252079 | P-Value: 0.983830291483408
# In the best result. Current Iteration: 1, current_col: diff_1
# Column: diff_1 | ADF Statistic: -3.2459749054155265 | P-Value: 0.017473009959041778
# In the best result. Current Iteration: 2, current_col: diff_2
# Column: diff_2 | ADF Statistic: -3.535879419339778 | P-Value: 0.007112053615698232
#
# ###############################################
#
# Best Result: Column: diff_2 | ADF Statistic: -3.535879419339778
# P-Value: 0.007112053615698232 | Passed? True | Num Diffs: 2
#
# ###############################################
#
# (15, 6)
# Best Num Differences: 2
# ARIMA(0, 2, 0) RMSE=47171.434
# ARIMA(0, 2, 1) RMSE=27871.135
# Input contains NaN, infinity or a value too large for dtype('float64').
# ARIMA(0, 2, 3) RMSE=14715.103
# ARIMA(0, 2, 4) RMSE=12900.897
# Schur decomposition solver error.
# ARIMA(2, 2, 1) RMSE=11869.705
# Schur decomposition solver error.
# ARIMA(3, 2, 0) RMSE=11769.582
# ARIMA(3, 2, 1) RMSE=10857.379
# Schur decomposition solver error.
# LU decomposition error.
# Schur decomposition solver error.
# LU decomposition error.
# LU decomposition error.
# Schur decomposition solver error.
# LU decomposition error.
# LU decomposition error.
# Schur decomposition solver error.
# Best ARIMA(3, 2, 1) RMSE=10857.379
# Run Completed. Dataframes Exported: "graph_ready", "export_ready"
# 22 of 105 completed
# Column: MedianIncome | ADF Statistic: 1.6771267087830681 | P-Value: 0.9980714655207146
# In the best result. Current Iteration: 1, current_col: diff_1
# Column: diff_1 | ADF Statistic: -0.6128421615157733 | P-Value: 0.8680537406888592
# In the best result. Current Iteration: 2, current_col: diff_2
# Column: diff_2 | ADF Statistic: -4.251957984947992 | P-Value: 0.0005374504785242531
#
# ###############################################
#
# Best Result: Column: diff_2 | ADF Statistic: -4.251957984947992
# P-Value: 0.0005374504785242531 | Passed? True | Num Diffs: 2
#
# ###############################################
#
# (15, 6)
# Best Num Differences: 2
# ARIMA(0, 2, 0) RMSE=13555.790
# ARIMA(0, 2, 1) RMSE=10186.768
# Input contains NaN, infinity or a value too large for dtype('float64').
# ARIMA(0, 2, 3) RMSE=8250.049
# ARIMA(0, 2, 4) RMSE=6108.327
# Schur decomposition solver error.
# LU decomposition error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# LU decomposition error.
# Schur decomposition solver error.
# LU decomposition error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Best ARIMA(0, 2, 4) RMSE=6108.327
# Run Completed. Dataframes Exported: "graph_ready", "export_ready"
# 23 of 105 completed
# Column: MedianIncome | ADF Statistic: 1.2617709454719241 | P-Value: 0.9963860710109751
# In the best result. Current Iteration: 1, current_col: diff_1
# Column: diff_1 | ADF Statistic: -5.917408437811208 | P-Value: 2.553451155930188e-07
# Column: diff_2 | ADF Statistic: -4.313909279069446 | P-Value: 0.0004202104960471577
#
# ###############################################
#
# Best Result: Column: diff_1 | ADF Statistic: -4.313909279069446
# P-Value: 0.0004202104960471577 | Passed? True | Num Diffs: 1
#
# ###############################################
#
# (15, 6)
# Best Num Differences: 1
# ARIMA(0, 1, 0) RMSE=5623.111
# ARIMA(0, 1, 1) RMSE=3559.149
# Input contains NaN, infinity or a value too large for dtype('float64').
# Input contains NaN, infinity or a value too large for dtype('float64').
# ARIMA(0, 1, 4) RMSE=3507.248
# ARIMA(1, 1, 1) RMSE=3410.405
# Schur decomposition solver error.
# Schur decomposition solver error.
# ARIMA(2, 1, 0) RMSE=3068.612
# ARIMA(2, 1, 1) RMSE=3014.576
# Schur decomposition solver error.
# Schur decomposition solver error.
# ARIMA(3, 1, 1) RMSE=2887.372
# Schur decomposition solver error.
# Schur decomposition solver error.
# ARIMA(3, 1, 4) RMSE=2068.064
# Schur decomposition solver error.
# Schur decomposition solver error.
# LU decomposition error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# LU decomposition error.
# LU decomposition error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Best ARIMA(3, 1, 4) RMSE=2068.064
# Schur decomposition solver error.
# Failure: local variable 'predicted_data' referenced before assignment, params: ['34005', '45-64']
# Column: MedianIncome | ADF Statistic: -0.4164337658147515 | P-Value: 0.9073185567953275
# In the best result. Current Iteration: 1, current_col: diff_1
# Column: diff_1 | ADF Statistic: -3.792199236096061 | P-Value: 0.0029881430138227415
# In the best result. Current Iteration: 2, current_col: diff_2
# Column: diff_2 | ADF Statistic: -4.867296896507924 | P-Value: 4.0363160678316985e-05
#
# ###############################################
#
# Best Result: Column: diff_2 | ADF Statistic: -4.867296896507924
# P-Value: 4.0363160678316985e-05 | Passed? True | Num Diffs: 2
#
# ###############################################
#
# (15, 6)
# Best Num Differences: 2
# ARIMA(0, 2, 0) RMSE=12985.392
# ARIMA(0, 2, 1) RMSE=7698.472
# Input contains NaN, infinity or a value too large for dtype('float64').
# ARIMA(0, 2, 3) RMSE=4369.348
# Schur decomposition solver error.
# ARIMA(1, 2, 4) RMSE=4089.289
# LU decomposition error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# LU decomposition error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# LU decomposition error.
# LU decomposition error.
# Schur decomposition solver error.
# Best ARIMA(1, 2, 4) RMSE=4089.289
# Run Completed. Dataframes Exported: "graph_ready", "export_ready"
# 25 of 105 completed
# Column: MedianIncome | ADF Statistic: -0.9792282245595653 | P-Value: 0.7607647426114642
# In the best result. Current Iteration: 1, current_col: diff_1
# Column: diff_1 | ADF Statistic: -5.654094703964834 | P-Value: 9.710014557407572e-07
# In the best result. Current Iteration: 2, current_col: diff_2
# Column: diff_2 | ADF Statistic: -7.268301903829816 | P-Value: 1.6131590761484212e-10
#
# ###############################################
#
# Best Result: Column: diff_2 | ADF Statistic: -7.268301903829816
# P-Value: 1.6131590761484212e-10 | Passed? True | Num Diffs: 2
#
# ###############################################
#
# (15, 6)
# Best Num Differences: 2
# ARIMA(0, 2, 0) RMSE=51148.328
# ARIMA(0, 2, 1) RMSE=29592.154
# Input contains NaN, infinity or a value too large for dtype('float64').
# ARIMA(0, 2, 3) RMSE=23949.584
# ARIMA(1, 2, 1) RMSE=19133.423
# Schur decomposition solver error.
# LU decomposition error.
# Schur decomposition solver error.
# LU decomposition error.
# Schur decomposition solver error.
# LU decomposition error.
# LU decomposition error.
# Schur decomposition solver error.
# LU decomposition error.
# Schur decomposition solver error.
# LU decomposition error.
# Schur decomposition solver error.
# Best ARIMA(1, 2, 1) RMSE=19133.423
# Run Completed. Dataframes Exported: "graph_ready", "export_ready"
# 26 of 105 completed
# Column: MedianIncome | ADF Statistic: -4.719998942865199 | P-Value: 7.716677498235149e-05
# Column: diff_1 | ADF Statistic: -2.5612641731230337 | P-Value: 0.10127033104732802
# Column: diff_2 | ADF Statistic: -4.610599545131179 | P-Value: 0.00012348198975246634
#
# ###############################################
#
# local variable 'best_col' referenced before assignment
# Failure: local variable 'predicted_data' referenced before assignment, params: ['34011', '45-64']
# Column: MedianIncome | ADF Statistic: -0.9510349083013586 | P-Value: 0.7707019112353244
# In the best result. Current Iteration: 1, current_col: diff_1
# Column: diff_1 | ADF Statistic: -4.036464193149441 | P-Value: 0.0012311604114041727
# In the best result. Current Iteration: 2, current_col: diff_2
# Column: diff_2 | ADF Statistic: -7.121674464062756 | P-Value: 3.7086497328349883e-10
#
# ###############################################
#
# Best Result: Column: diff_2 | ADF Statistic: -7.121674464062756
# P-Value: 3.7086497328349883e-10 | Passed? True | Num Diffs: 2
#
# ###############################################
#
# (15, 6)
# Best Num Differences: 2
# ARIMA(0, 2, 0) RMSE=19844.070
# ARIMA(0, 2, 1) RMSE=10148.753
# Input contains NaN, infinity or a value too large for dtype('float64').
# ARIMA(0, 2, 3) RMSE=8388.082
# ARIMA(0, 2, 4) RMSE=6635.083
# ARIMA(1, 2, 1) RMSE=6377.175
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# LU decomposition error.
# LU decomposition error.
# Schur decomposition solver error.
# LU decomposition error.
# Schur decomposition solver error.
# LU decomposition error.
# LU decomposition error.
# Best ARIMA(1, 2, 1) RMSE=6377.175
# Run Completed. Dataframes Exported: "graph_ready", "export_ready"
# 28 of 105 completed
# Column: MedianIncome | ADF Statistic: 0.37549380501581275 | P-Value: 0.9805550017092292
# In the best result. Current Iteration: 1, current_col: diff_1
# Column: diff_1 | ADF Statistic: -1.4895165381887028 | P-Value: 0.5386908363455242
# In the best result. Current Iteration: 2, current_col: diff_2
# Column: diff_2 | ADF Statistic: -3.257338408188271 | P-Value: 0.01689653068909198
#
# ###############################################
#
# Best Result: Column: diff_2 | ADF Statistic: -3.257338408188271
# P-Value: 0.01689653068909198 | Passed? True | Num Diffs: 2
#
# ###############################################
#
# (15, 6)
# Best Num Differences: 2
# ARIMA(0, 2, 0) RMSE=26888.110
# ARIMA(0, 2, 1) RMSE=16957.587
# Input contains NaN, infinity or a value too large for dtype('float64').
# ARIMA(0, 2, 3) RMSE=15810.219
# ARIMA(0, 2, 4) RMSE=11702.763
# Schur decomposition solver error.
# ARIMA(1, 2, 4) RMSE=10179.747
# Schur decomposition solver error.
# ARIMA(2, 2, 3) RMSE=9156.584
# ARIMA(2, 2, 4) RMSE=8515.788
# ARIMA(3, 2, 1) RMSE=8032.379
# Schur decomposition solver error.
# ARIMA(3, 2, 4) RMSE=7964.671
# LU decomposition error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# LU decomposition error.
# LU decomposition error.
# Schur decomposition solver error.
# Best ARIMA(3, 2, 4) RMSE=7964.671
# Run Completed. Dataframes Exported: "graph_ready", "export_ready"
# 29 of 105 completed
# Column: MedianIncome | ADF Statistic: 1.3648135044666327 | P-Value: 0.9969482831494757
# In the best result. Current Iteration: 1, current_col: diff_1
# Column: diff_1 | ADF Statistic: -2.2963661679937712 | P-Value: 0.17314263326599777
# Column: diff_2 | ADF Statistic: -1.543738905909953 | P-Value: 0.5117741563269068
#
# ###############################################
#
# Best Result: Column: diff_1 | ADF Statistic: -1.543738905909953
# P-Value: 0.5117741563269068 | Passed? False | Num Diffs: 1
#
# ###############################################
#
# (15, 6)
# Best Num Differences: 1
# ARIMA(0, 1, 0) RMSE=5817.607
# ARIMA(0, 1, 1) RMSE=4516.495
# Input contains NaN, infinity or a value too large for dtype('float64').
# Input contains NaN, infinity or a value too large for dtype('float64').
# ARIMA(0, 1, 4) RMSE=3808.642
# Schur decomposition solver error.
# Schur decomposition solver error.
# ARIMA(1, 1, 4) RMSE=3413.841
# Schur decomposition solver error.
# Schur decomposition solver error.
# ARIMA(3, 1, 0) RMSE=3218.866
# Schur decomposition solver error.
# Schur decomposition solver error.
# LU decomposition error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# LU decomposition error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# ARIMA(5, 1, 4) RMSE=3032.504
# LU decomposition error.
# LU decomposition error.
# Schur decomposition solver error.
# LU decomposition error.
# Best ARIMA(5, 1, 4) RMSE=3032.504
# Schur decomposition solver error.
# Failure: local variable 'predicted_data' referenced before assignment, params: ['34017', '45-64']
# Column: MedianIncome | ADF Statistic: -1.1419007061162088 | P-Value: 0.6980765713411926
# In the best result. Current Iteration: 1, current_col: diff_1
# Column: diff_1 | ADF Statistic: -4.062784641063662 | P-Value: 0.0011151812556400272
# Column: diff_2 | ADF Statistic: -2.9644275016268256 | P-Value: 0.038352624138523195
#
# ###############################################
#
# Best Result: Column: diff_1 | ADF Statistic: -2.9644275016268256
# P-Value: 0.038352624138523195 | Passed? True | Num Diffs: 1
#
# ###############################################
#
# (15, 6)
# Best Num Differences: 1
# ARIMA(0, 1, 0) RMSE=22709.459
# ARIMA(0, 1, 1) RMSE=13791.547
# Input contains NaN, infinity or a value too large for dtype('float64').
# Input contains NaN, infinity or a value too large for dtype('float64').
# Schur decomposition solver error.
# Schur decomposition solver error.
# ARIMA(2, 1, 1) RMSE=13714.559
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# LU decomposition error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Best ARIMA(2, 1, 1) RMSE=13714.559
# Run Completed. Dataframes Exported: "graph_ready", "export_ready"
# 31 of 105 completed
# Column: MedianIncome | ADF Statistic: 0.9877806465152266 | P-Value: 0.9941353323193636
# In the best result. Current Iteration: 1, current_col: diff_1
# Column: diff_1 | ADF Statistic: -1.92157804901942 | P-Value: 0.3219791882081624
# In the best result. Current Iteration: 2, current_col: diff_2
# Column: diff_2 | ADF Statistic: -10.307731661706557 | P-Value: 3.2455706040416708e-18
#
# ###############################################
#
# Best Result: Column: diff_2 | ADF Statistic: -10.307731661706557
# P-Value: 3.2455706040416708e-18 | Passed? True | Num Diffs: 2
#
# ###############################################
#
# (15, 6)
# Best Num Differences: 2
# ARIMA(0, 2, 0) RMSE=16037.353
# ARIMA(0, 2, 1) RMSE=10208.795
# Input contains NaN, infinity or a value too large for dtype('float64').
# ARIMA(0, 2, 3) RMSE=7396.342
# Schur decomposition solver error.
# ARIMA(1, 2, 4) RMSE=7139.976
# Schur decomposition solver error.
# ARIMA(2, 2, 3) RMSE=5151.569
# ARIMA(2, 2, 4) RMSE=4630.977
# LU decomposition error.
# Schur decomposition solver error.
# LU decomposition error.
# Schur decomposition solver error.
# LU decomposition error.
# Schur decomposition solver error.
# ARIMA(6, 2, 0) RMSE=2094.232
# Schur decomposition solver error.
# Best ARIMA(6, 2, 0) RMSE=2094.232
# Run Completed. Dataframes Exported: "graph_ready", "export_ready"
# 32 of 105 completed
# Column: MedianIncome | ADF Statistic: 0.9596699627841546 | P-Value: 0.9938216566343185
# In the best result. Current Iteration: 1, current_col: diff_1
# Column: diff_1 | ADF Statistic: -0.6714952822409511 | P-Value: 0.853995407005517
# In the best result. Current Iteration: 2, current_col: diff_2
# Column: diff_2 | ADF Statistic: -2.1519352657373387 | P-Value: 0.2241500538806923
#
# ###############################################
#
# Best Result: Column: diff_2 | ADF Statistic: -2.1519352657373387
# P-Value: 0.2241500538806923 | Passed? False | Num Diffs: 2
#
# ###############################################
#
# (15, 6)
# Best Num Differences: 2
# ARIMA(0, 2, 0) RMSE=10408.485
# ARIMA(0, 2, 1) RMSE=6717.497
# Input contains NaN, infinity or a value too large for dtype('float64').
# ARIMA(0, 2, 3) RMSE=5182.404
# Schur decomposition solver error.
# ARIMA(1, 2, 4) RMSE=4688.665
# LU decomposition error.
# Schur decomposition solver error.
# LU decomposition error.
# LU decomposition error.
# LU decomposition error.
# LU decomposition error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Best ARIMA(1, 2, 4) RMSE=4688.665
# Run Completed. Dataframes Exported: "graph_ready", "export_ready"
# 33 of 105 completed
# Column: MedianIncome | ADF Statistic: 2.3450138050561224 | P-Value: 0.9989820367824995
# In the best result. Current Iteration: 1, current_col: diff_1
# Column: diff_1 | ADF Statistic: -0.7411771948017589 | P-Value: 0.8357935411907155
# In the best result. Current Iteration: 2, current_col: diff_2
# Column: diff_2 | ADF Statistic: -2.767946585591774 | P-Value: 0.06300024694621238
#
# ###############################################
#
# Best Result: Column: diff_2 | ADF Statistic: -2.767946585591774
# P-Value: 0.06300024694621238 | Passed? False | Num Diffs: 2
#
# ###############################################
#
# (15, 6)
# Best Num Differences: 2
# ARIMA(0, 2, 0) RMSE=23289.824
# ARIMA(0, 2, 1) RMSE=14995.038
# Input contains NaN, infinity or a value too large for dtype('float64').
# ARIMA(0, 2, 3) RMSE=8583.848
# Schur decomposition solver error.
# Schur decomposition solver error.
# ARIMA(2, 2, 3) RMSE=8283.684
# Schur decomposition solver error.
# LU decomposition error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# LU decomposition error.
# LU decomposition error.
# Schur decomposition solver error.
# Best ARIMA(2, 2, 3) RMSE=8283.684
# LU decomposition error.
# Failure: local variable 'predicted_data' referenced before assignment, params: ['34025', '45-64']
# Column: MedianIncome | ADF Statistic: 0.975769217971929 | P-Value: 0.9940035909842139
# In the best result. Current Iteration: 1, current_col: diff_1
# Column: diff_1 | ADF Statistic: -3.0727645314143244 | P-Value: 0.028635497182719183
# In the best result. Current Iteration: 2, current_col: diff_2
# Column: diff_2 | ADF Statistic: -3.816178810598204 | P-Value: 0.00274605509057455
#
# ###############################################
#
# Best Result: Column: diff_2 | ADF Statistic: -3.816178810598204
# P-Value: 0.00274605509057455 | Passed? True | Num Diffs: 2
#
# ###############################################
#
# (15, 6)
# Best Num Differences: 2
# ARIMA(0, 2, 0) RMSE=13047.317
# ARIMA(0, 2, 1) RMSE=8341.390
# Input contains NaN, infinity or a value too large for dtype('float64').
# ARIMA(0, 2, 3) RMSE=6062.465
# Schur decomposition solver error.
# ARIMA(1, 2, 4) RMSE=4822.155
# ARIMA(2, 2, 1) RMSE=4722.773
# Schur decomposition solver error.
# Schur decomposition solver error.
# LU decomposition error.
# LU decomposition error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Best ARIMA(2, 2, 1) RMSE=4722.773
# Run Completed. Dataframes Exported: "graph_ready", "export_ready"
# 35 of 105 completed
# Column: MedianIncome | ADF Statistic: 2.799356367153935 | P-Value: 1.0
# In the best result. Current Iteration: 1, current_col: diff_1
# Column: diff_1 | ADF Statistic: -2.001401010558706 | P-Value: 0.2859591429357084
# In the best result. Current Iteration: 2, current_col: diff_2
# Column: diff_2 | ADF Statistic: -4.458937735402618 | P-Value: 0.00023310777261748573
#
# ###############################################
#
# Best Result: Column: diff_2 | ADF Statistic: -4.458937735402618
# P-Value: 0.00023310777261748573 | Passed? True | Num Diffs: 2
#
# ###############################################
#
# (15, 6)
# Best Num Differences: 2
# ARIMA(0, 2, 0) RMSE=17011.124
# ARIMA(0, 2, 1) RMSE=10688.043
# Input contains NaN, infinity or a value too large for dtype('float64').
# ARIMA(0, 2, 3) RMSE=9566.991
# Schur decomposition solver error.
# LU decomposition error.
# LU decomposition error.
# Schur decomposition solver error.
# ARIMA(4, 2, 1) RMSE=8160.511
# Schur decomposition solver error.
# LU decomposition error.
# LU decomposition error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Best ARIMA(4, 2, 1) RMSE=8160.511
# Run Completed. Dataframes Exported: "graph_ready", "export_ready"
# 36 of 105 completed
# Column: MedianIncome | ADF Statistic: 2.0065390947088337 | P-Value: 0.9986813880284648
# In the best result. Current Iteration: 1, current_col: diff_1
# Column: diff_1 | ADF Statistic: 1.6738129629468237 | P-Value: 0.9980629594789453
# In the best result. Current Iteration: 2, current_col: diff_2
# Column: diff_2 | ADF Statistic: -3.3264208218072104 | P-Value: 0.013737986837818733
#
# ###############################################
#
# Best Result: Column: diff_2 | ADF Statistic: -3.3264208218072104
# P-Value: 0.013737986837818733 | Passed? True | Num Diffs: 2
#
# ###############################################
#
# (15, 6)
# Best Num Differences: 2
# ARIMA(0, 2, 0) RMSE=51469.679
# ARIMA(0, 2, 1) RMSE=29398.495
# Input contains NaN, infinity or a value too large for dtype('float64').
# ARIMA(0, 2, 3) RMSE=15911.492
# ARIMA(0, 2, 4) RMSE=12971.141
# ARIMA(1, 2, 0) RMSE=10885.127
# ARIMA(1, 2, 1) RMSE=7515.396
# Schur decomposition solver error.
# LU decomposition error.
# Schur decomposition solver error.
# LU decomposition error.
# Schur decomposition solver error.
# LU decomposition error.
# Schur decomposition solver error.
# LU decomposition error.
# LU decomposition error.
# Schur decomposition solver error.
# LU decomposition error.
# Schur decomposition solver error.
# LU decomposition error.
# Best ARIMA(1, 2, 1) RMSE=7515.396
# Run Completed. Dataframes Exported: "graph_ready", "export_ready"
# 37 of 105 completed
# Column: MedianIncome | ADF Statistic: -4.527725750742762 | P-Value: 0.00017515923081232003
# Column: diff_1 | ADF Statistic: -1.7358421254511127 | P-Value: 0.4127465261645521
# Column: diff_2 | ADF Statistic: -2.101666429346252 | P-Value: 0.24384505008292834
#
# ###############################################
#
# local variable 'best_col' referenced before assignment
# Failure: local variable 'predicted_data' referenced before assignment, params: ['34033', '45-64']
# Column: MedianIncome | ADF Statistic: -1.4185604671320202 | P-Value: 0.5733463650823625
# Column: diff_1 | ADF Statistic: 0.3217145092381765 | P-Value: 0.9783190928570177
# In the best result. Current Iteration: 2, current_col: diff_2
# Column: diff_2 | ADF Statistic: -5.300587460673055 | P-Value: 5.460331398616506e-06
#
# ###############################################
#
# Best Result: Column: diff_2 | ADF Statistic: -5.300587460673055
# P-Value: 5.460331398616506e-06 | Passed? True | Num Diffs: 2
#
# ###############################################
#
# (15, 6)
# Best Num Differences: 2
# ARIMA(0, 2, 0) RMSE=40529.006
# ARIMA(0, 2, 1) RMSE=22604.447
# Input contains NaN, infinity or a value too large for dtype('float64').
# ARIMA(0, 2, 3) RMSE=14474.853
# Schur decomposition solver error.
# Schur decomposition solver error.
# LU decomposition error.
# ...
# Column: diff_1 | ADF Statistic: -5.996723240481957 | P-Value: 1.6947008683733915e-07
# Column: diff_2 | ADF Statistic: -5.771789880474238 | P-Value: 5.371207143413581e-07
#
# ###############################################
#
# Best Result: Column: diff_1 | ADF Statistic: -5.771789880474238
# P-Value: 5.371207143413581e-07 | Passed? True | Num Diffs: 1
#
# ###############################################
#
# (15, 6)
# Best Num Differences: 1
# ARIMA(0, 1, 0) RMSE=8821.302
# ARIMA(0, 1, 1) RMSE=6857.460
# Input contains NaN, infinity or a value too large for dtype('float64').
# Input contains NaN, infinity or a value too large for dtype('float64').
# Schur decomposition solver error.
# Schur decomposition solver error.
# ARIMA(1, 1, 4) RMSE=6627.716
# ARIMA(2, 1, 0) RMSE=5894.188
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# LU decomposition error.
# LU decomposition error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# LU decomposition error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Best ARIMA(2, 1, 0) RMSE=5894.188
# Run Completed. Dataframes Exported: "graph_ready", "export_ready"
# 93 of 105 completed
# Column: MedianIncome | ADF Statistic: -3.4781158749194607 | P-Value: 0.008567236967508468
# Column: diff_1 | ADF Statistic: 0.14615696779210588 | P-Value: 0.9690747721391655
# Column: diff_2 | ADF Statistic: -2.9476039810431294 | P-Value: 0.040085767183094055
#
# ###############################################
#
# local variable 'best_col' referenced before assignment
# Failure: local variable 'predicted_data' referenced before assignment, params: ['34019', 'under-25']
# Column: MedianIncome | ADF Statistic: -3.843391860962581 | P-Value: 0.0024932881044322144
# In the best result. Current Iteration: 1, current_col: diff_1
# Column: diff_1 | ADF Statistic: -6.325117109654123 | P-Value: 2.999569615228815e-08
# Column: diff_2 | ADF Statistic: -2.970752403460488 | P-Value: 0.03771750933144069
#
# ###############################################
#
# Best Result: Column: diff_1 | ADF Statistic: -2.970752403460488
# P-Value: 0.03771750933144069 | Passed? True | Num Diffs: 1
#
# ###############################################
#
# (15, 6)
# Best Num Differences: 1
# ARIMA(0, 1, 0) RMSE=31560.211
# ARIMA(0, 1, 1) RMSE=19557.382
# Input contains NaN, infinity or a value too large for dtype('float64').
# Input contains NaN, infinity or a value too large for dtype('float64').
# ARIMA(1, 1, 1) RMSE=19436.867
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# LU decomposition error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# LU decomposition error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# LU decomposition error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Best ARIMA(1, 1, 1) RMSE=19436.867
# Run Completed. Dataframes Exported: "graph_ready", "export_ready"
# 95 of 105 completed
# Column: MedianIncome | ADF Statistic: -1.6055491785535598 | P-Value: 0.4808053924039298
# In the best result. Current Iteration: 1, current_col: diff_1
# Column: diff_1 | ADF Statistic: -18.273259147905016 | P-Value: 2.3170520268384527e-30
# Column: diff_2 | ADF Statistic: -4.704018315581704 | P-Value: 8.270221648847498e-05
#
# ###############################################
#
# Best Result: Column: diff_1 | ADF Statistic: -4.704018315581704
# P-Value: 8.270221648847498e-05 | Passed? True | Num Diffs: 1
#
# ###############################################
#
# (15, 6)
# Best Num Differences: 1
# ARIMA(0, 1, 0) RMSE=14037.508
# ARIMA(0, 1, 1) RMSE=8192.618
# Input contains NaN, infinity or a value too large for dtype('float64').
# Input contains NaN, infinity or a value too large for dtype('float64').
# Schur decomposition solver error.
# Schur decomposition solver error.
# ARIMA(1, 1, 4) RMSE=7861.603
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# LU decomposition error.
# LU decomposition error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Best ARIMA(1, 1, 4) RMSE=7861.603
# Schur decomposition solver error.
# Failure: local variable 'predicted_data' referenced before assignment, params: ['34023', 'under-25']
# Column: MedianIncome | ADF Statistic: -2.944040805357484 | P-Value: 0.040461130487344246
# In the best result. Current Iteration: 1, current_col: diff_1
# Column: diff_1 | ADF Statistic: -4.2148219602345085 | P-Value: 0.0006218514060742464
# Column: diff_2 | ADF Statistic: -2.2241666907339845 | P-Value: 0.1975915395663767
#
# ###############################################
#
# Best Result: Column: diff_1 | ADF Statistic: -2.2241666907339845
# P-Value: 0.1975915395663767 | Passed? False | Num Diffs: 1
#
# ###############################################
#
# (15, 6)
# Best Num Differences: 1
# ARIMA(0, 1, 0) RMSE=18327.614
# ARIMA(0, 1, 1) RMSE=13722.255
# Input contains NaN, infinity or a value too large for dtype('float64').
# Input contains NaN, infinity or a value too large for dtype('float64').
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# LU decomposition error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# LU decomposition error.
# LU decomposition error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# LU decomposition error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Best ARIMA(0, 1, 1) RMSE=13722.255
# Run Completed. Dataframes Exported: "graph_ready", "export_ready"
# 97 of 105 completed
# Column: MedianIncome | ADF Statistic: -2.4134997246029575 | P-Value: 0.13796240638673557
# In the best result. Current Iteration: 1, current_col: diff_1
# Column: diff_1 | ADF Statistic: -2.7616005092759432 | P-Value: 0.06397165736837596
# In the best result. Current Iteration: 2, current_col: diff_2
# Column: diff_2 | ADF Statistic: -7.673843603802813 | P-Value: 1.5677424643855375e-11
#
# ###############################################
#
# Best Result: Column: diff_2 | ADF Statistic: -7.673843603802813
# P-Value: 1.5677424643855375e-11 | Passed? True | Num Diffs: 2
#
# ###############################################
#
# (15, 6)
# Best Num Differences: 2
# ARIMA(0, 2, 0) RMSE=77664.968
# ARIMA(0, 2, 1) RMSE=45387.811
# Input contains NaN, infinity or a value too large for dtype('float64').
# ARIMA(0, 2, 3) RMSE=25047.263
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# LU decomposition error.
# Schur decomposition solver error.
# LU decomposition error.
# LU decomposition error.
# Schur decomposition solver error.
# LU decomposition error.
# Schur decomposition solver error.
# Best ARIMA(0, 2, 3) RMSE=25047.263
# Run Completed. Dataframes Exported: "graph_ready", "export_ready"
# 98 of 105 completed
# Column: MedianIncome | ADF Statistic: -3.3218016389230627 | P-Value: 0.013931625994074425
# In the best result. Current Iteration: 1, current_col: diff_1
# Column: diff_1 | ADF Statistic: -5.702103564298814 | P-Value: 7.63406285843028e-07
# Column: diff_2 | ADF Statistic: -2.7883254047959634 | P-Value: 0.05996084912476503
#
# ###############################################
#
# Best Result: Column: diff_1 | ADF Statistic: -2.7883254047959634
# P-Value: 0.05996084912476503 | Passed? False | Num Diffs: 1
#
# ###############################################
#
# (15, 6)
# Best Num Differences: 1
# ARIMA(0, 1, 0) RMSE=32171.174
# ARIMA(0, 1, 1) RMSE=21223.108
# Input contains NaN, infinity or a value too large for dtype('float64').
# Input contains NaN, infinity or a value too large for dtype('float64').
# ARIMA(1, 1, 1) RMSE=20545.026
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# ARIMA(3, 1, 1) RMSE=20523.610
# Schur decomposition solver error.
# Schur decomposition solver error.
# LU decomposition error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# LU decomposition error.
# LU decomposition error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# LU decomposition error.
# LU decomposition error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Best ARIMA(3, 1, 1) RMSE=20523.610
# Run Completed. Dataframes Exported: "graph_ready", "export_ready"
# 99 of 105 completed
# Column: MedianIncome | ADF Statistic: 4.342789011470793 | P-Value: 1.0
# In the best result. Current Iteration: 1, current_col: diff_1
# Column: diff_1 | ADF Statistic: 2.3146137498044 | P-Value: 0.9989642797861303
# In the best result. Current Iteration: 2, current_col: diff_2
# Column: diff_2 | ADF Statistic: -5.4127976161875635 | P-Value: 3.183748938708381e-06
#
# ###############################################
#
# Best Result: Column: diff_2 | ADF Statistic: -5.4127976161875635
# P-Value: 3.183748938708381e-06 | Passed? True | Num Diffs: 2
#
# ###############################################
#
# (15, 6)
# Best Num Differences: 2
# ARIMA(0, 2, 0) RMSE=78345.837
# ARIMA(0, 2, 1) RMSE=46376.090
# Input contains NaN, infinity or a value too large for dtype('float64').
# ARIMA(0, 2, 3) RMSE=25871.830
# ARIMA(0, 2, 4) RMSE=24463.499
# Schur decomposition solver error.
# LU decomposition error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# LU decomposition error.
# Schur decomposition solver error.
# LU decomposition error.
# Schur decomposition solver error.
# Best ARIMA(0, 2, 4) RMSE=24463.499
# Run Completed. Dataframes Exported: "graph_ready", "export_ready"
# 100 of 105 completed
# Column: MedianIncome | ADF Statistic: -0.42713950800285716 | P-Value: 0.9054678862003271
# In the best result. Current Iteration: 1, current_col: diff_1
# Column: diff_1 | ADF Statistic: -1.4022707070762759 | P-Value: 0.5811870301547755
# In the best result. Current Iteration: 2, current_col: diff_2
# Column: diff_2 | ADF Statistic: -5.613013245644301 | P-Value: 1.1916058153227661e-06
#
# ###############################################
#
# Best Result: Column: diff_2 | ADF Statistic: -5.613013245644301
# P-Value: 1.1916058153227661e-06 | Passed? True | Num Diffs: 2
#
# ###############################################
#
# (15, 6)
# Best Num Differences: 2
# ARIMA(0, 2, 0) RMSE=90289.851
# ARIMA(0, 2, 1) RMSE=59312.287
# Input contains NaN, infinity or a value too large for dtype('float64').
# ARIMA(0, 2, 3) RMSE=49616.869
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# LU decomposition error.
# LU decomposition error.
# Schur decomposition solver error.
# LU decomposition error.
# Schur decomposition solver error.
# LU decomposition error.
# Schur decomposition solver error.
# Best ARIMA(0, 2, 3) RMSE=49616.869
# Run Completed. Dataframes Exported: "graph_ready", "export_ready"
# 101 of 105 completed
# Column: MedianIncome | ADF Statistic: -4.683698369067644 | P-Value: 9.029110722062319e-05
# In the best result. Current Iteration: 1, current_col: diff_1
# Column: diff_1 | ADF Statistic: -4.878753597571738 | P-Value: 3.835194444097109e-05
# In the best result. Current Iteration: 2, current_col: diff_2
# Column: diff_2 | ADF Statistic: -6.0631929565217195 | P-Value: 1.1988768555029421e-07
#
# ###############################################
#
# Best Result: Column: diff_2 | ADF Statistic: -6.0631929565217195
# P-Value: 1.1988768555029421e-07 | Passed? True | Num Diffs: 2
#
# ###############################################
#
# (15, 6)
# Best Num Differences: 2
# ARIMA(0, 2, 0) RMSE=143896.997
# ARIMA(0, 2, 1) RMSE=78296.645
# Input contains NaN, infinity or a value too large for dtype('float64').
# ARIMA(0, 2, 3) RMSE=48188.183
# ARIMA(0, 2, 4) RMSE=44540.437
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# LU decomposition error.
# Schur decomposition solver error.
# LU decomposition error.
# Schur decomposition solver error.
# LU decomposition error.
# Schur decomposition solver error.
# Best ARIMA(0, 2, 4) RMSE=44540.437
# Run Completed. Dataframes Exported: "graph_ready", "export_ready"
# 102 of 105 completed
# Column: MedianIncome | ADF Statistic: -1.7900327477038833 | P-Value: 0.3854212652637643
# Column: diff_1 | ADF Statistic: 41.73704254973967 | P-Value: 1.0
# In the best result. Current Iteration: 2, current_col: diff_2
# Column: diff_2 | ADF Statistic: -10.994717598759667 | P-Value: 6.917537739857578e-20
#
# ###############################################
#
# Best Result: Column: diff_2 | ADF Statistic: -10.994717598759667
# P-Value: 6.917537739857578e-20 | Passed? True | Num Diffs: 2
#
# ###############################################
#
# (15, 6)
# Best Num Differences: 2
# ARIMA(0, 2, 0) RMSE=87595.203
# ARIMA(0, 2, 1) RMSE=58956.937
# Input contains NaN, infinity or a value too large for dtype('float64').
# ARIMA(0, 2, 3) RMSE=45240.555
# ARIMA(0, 2, 4) RMSE=42293.419
# Schur decomposition solver error.
# ARIMA(2, 2, 1) RMSE=32573.906
# Schur decomposition solver error.
# ARIMA(3, 2, 1) RMSE=31420.866
# LU decomposition error.
# LU decomposition error.
# Schur decomposition solver error.
# LU decomposition error.
# Schur decomposition solver error.
# LU decomposition error.
# Schur decomposition solver error.
# Best ARIMA(3, 2, 1) RMSE=31420.866
# Run Completed. Dataframes Exported: "graph_ready", "export_ready"
# 103 of 105 completed
# Column: MedianIncome | ADF Statistic: -3.817355203679926 | P-Value: 0.0027346571096687005
# In the best result. Current Iteration: 1, current_col: diff_1
# Column: diff_1 | ADF Statistic: -4.43299758743702 | P-Value: 0.0002593642568467104
# In the best result. Current Iteration: 2, current_col: diff_2
# Column: diff_2 | ADF Statistic: -4.9672920851013025 | P-Value: 2.5750091250667124e-05
#
# ###############################################
#
# Best Result: Column: diff_2 | ADF Statistic: -4.9672920851013025
# P-Value: 2.5750091250667124e-05 | Passed? True | Num Diffs: 2
#
# ###############################################
#
# (15, 6)
# Best Num Differences: 2
# ARIMA(0, 2, 0) RMSE=52497.173
# ARIMA(0, 2, 1) RMSE=35665.757
# Input contains NaN, infinity or a value too large for dtype('float64').
# ARIMA(0, 2, 3) RMSE=25079.518
# ARIMA(0, 2, 4) RMSE=24840.939
# Schur decomposition solver error.
# ARIMA(2, 2, 1) RMSE=22795.377
# Schur decomposition solver error.
# LU decomposition error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# LU decomposition error.
# LU decomposition error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Best ARIMA(2, 2, 1) RMSE=22795.377
# Run Completed. Dataframes Exported: "graph_ready", "export_ready"
# 104 of 105 completed
# Column: MedianIncome | ADF Statistic: -2.0333759496829016 | P-Value: 0.2721333037554947
# Column: diff_1 | ADF Statistic: 0.5641377984166428 | P-Value: 0.9866975099080524
# In the best result. Current Iteration: 2, current_col: diff_2
# Column: diff_2 | ADF Statistic: -9.954571405771707 | P-Value: 2.4636070168719657e-17
#
# ###############################################
#
# Best Result: Column: diff_2 | ADF Statistic: -9.954571405771707
# P-Value: 2.4636070168719657e-17 | Passed? True | Num Diffs: 2
#
# ###############################################
#
# (15, 6)
# Best Num Differences: 2
# ARIMA(0, 2, 0) RMSE=95557.805
# ARIMA(0, 2, 1) RMSE=49779.661
# Input contains NaN, infinity or a value too large for dtype('float64').
# ARIMA(0, 2, 3) RMSE=35203.518
# ARIMA(0, 2, 4) RMSE=31556.221
# Schur decomposition solver error.
# Schur decomposition solver error.
# LU decomposition error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Best ARIMA(0, 2, 4) RMSE=31556.221
# Run Completed. Dataframes Exported: "graph_ready", "export_ready"
# 105 of 105 completed

# %%
main_frame = pd.DataFrame()
for frame in prediction_dataframes:
    frame['FIPS'] = frame['FIPS'].tolist()[0]
    main_frame = pd.concat([main_frame, frame])

# %%
main_frame.to_csv('PredictedIncomeFinal.csv',index = False)

# %%
main_frame.head(50)
# Out:
#     Year   FIPS  MedianIncome AgeGroup  train_and_predicted
# 0   2005  34001       52040.0    25-44                  NaN
# 1   2006  34001       57582.0    25-44                  NaN
# 2   2007  34001       61533.0    25-44                  NaN
# 3   2008  34001       54092.0    25-44                  NaN
# 4   2009  34001       61628.0    25-44                  NaN
# 5   2010  34001       49904.0    25-44                  NaN
# 6   2011  34001       50104.0    25-44                  NaN
# 7   2012  34001       51046.0    25-44                  NaN
# 8   2013  34001       52766.0    25-44                  NaN
# 9   2014  34001       54343.0    25-44                  NaN
# 10  2015  34001       56660.0    25-44                  NaN
# 11  2016  34001       56332.0    25-44                  NaN
# 12  2017  34001       65295.0    25-44                  NaN
# 13  2018  34001       61793.0    25-44                  NaN
# 14  2019  34001       65106.0    25-44                  NaN
# 15  2020  34001           NaN    25-44         64806.352802
# 16  2021  34001           NaN    25-44         65173.141791
# 17  2022  34001           NaN    25-44         65149.951360
# 18  2023  34001           NaN    25-44         65190.852772
# 19  2024  34001           NaN    25-44         65189.425842
# 20  2025  34001           NaN    25-44         65194.020912
# 21  2026  34001           NaN    25-44         65193.994199
# 22  2027  34001           NaN    25-44         65194.514359
# 23  2028  34001           NaN    25-44         65194.526619
# 24  2029  34001           NaN    25-44         65194.585950
# 0   2005  34003       79122.0    25-44                  NaN
# 1   2006  34003       82115.0    25-44                  NaN
# 2   2007  34003       86144.0    25-44                  NaN
# 3   2008  34003       83599.0    25-44                  NaN
# 4   2009  34003       85638.0    25-44                  NaN
# 5   2010  34003       82334.0    25-44                  NaN
# 6   2011  34003       89101.0    25-44                  NaN
# 7   2012  34003       92210.0    25-44                  NaN
# 8   2013  34003       85633.0    25-44                  NaN
# 9   2014  34003       88932.0    25-44                  NaN
# 10  2015  34003      100285.0    25-44                  NaN
# 11  2016  34003      101172.0    25-44                  NaN
# 12  2017  34003      102075.0    25-44                  NaN
# 13  2018  34003      110642.0    25-44                  NaN
# 14  2019  34003      119900.0    25-44                  NaN
# 15  2020  34003           NaN    25-44        127555.338213
# 16  2021  34003           NaN    25-44        133885.948335
# 17  2022  34003           NaN    25-44        140145.661988
# 18  2023  34003           NaN    25-44        146405.375641
# 19  2024  34003           NaN    25-44        152665.089294
# 20  2025  34003           NaN    25-44        158924.802947
# 21  2026  34003           NaN    25-44        165184.516600
# 22  2027  34003           NaN    25-44        171444.230253
# 23  2028  34003           NaN    25-44        177703.943906
# 24  2029  34003           NaN    25-44        183963.657559

# %%
prediction_dataframes[7]
# Out:
#     Year   FIPS  MedianIncome AgeGroup  train_and_predicted
# 0   2005  34015       72375.0    25-44                  NaN
# 1   2006  34015       75948.0    25-44                  NaN
# 2   2007  34015       79959.0    25-44                  NaN
# 3   2008  34015       77282.0    25-44                  NaN
# 4   2009  34015       77956.0    25-44                  NaN
# 5   2010  34015       81491.0    25-44                  NaN
# 6   2011  34015       79688.0    25-44                  NaN
# 7   2012  34015       82107.0    25-44                  NaN
# 8   2013  34015       76737.0    25-44                  NaN
# 9   2014  34015       93984.0    25-44                  NaN
# 10  2015  34015       88084.0    25-44                  NaN
# 11  2016  34015       93758.0    25-44                  NaN
# 12  2017  34015      101685.0    25-44                  NaN
# 13  2018  34015       99834.0    25-44                  NaN
# 14  2019  34015      101800.0    25-44                  NaN
# 15  2020    NaN           NaN    25-44        103923.778300
# 16  2021    NaN           NaN    25-44        107426.885261
# 17  2022    NaN           NaN    25-44        111502.340205
# 18  2023    NaN           NaN    25-44        115527.678072
# 19  2024    NaN           NaN    25-44        119553.015939
# 20  2025    NaN           NaN    25-44        123578.353806
# 21  2026    NaN           NaN    25-44        127603.691673
# 22  2027    NaN           NaN    25-44        131629.029540
# 23  2028    NaN           NaN    25-44        135654.367407
# 24  2029    NaN           NaN    25-44        139679.705274

# %%
print('this')
# Out:
# this

# %% [markdown]
# # Exploration below this line. The code is messy...

# %%
assert 1 == 2 # Not kidding. You don't want to run this stuff.
# Get the filtered data
filtered_df = arm.filter_data(master_table, target, params)
adf_filtered_df, best_col, num_diffs = arm.get_adf(filtered_df, target)

# %%
ready_for_undiff, num_diffs = arm.control_arima(master_table, target, params)

# %%
ready_for_undiff

# %%
df = adf_filtered_df.copy()

#df = ready_for_undiff.copy()
target = 'diff_2'
num_diffs = 2
df['moving_diff'] = df[base_column]
for i in range(0,num_diffs):
    df['moving_diff'] = df['moving_diff'].shift(-num_diffs)
    df[target] = df[target].shift(-num_diffs)
    
    df['moving_diff'] = df['moving_diff'] + df['MedianIncome']
    
df['moving_diff']
    
df

# %%
df['trained'] = df['train_set'].shift(-1)
df['diff_2'] = df['diff_2'].shift(-2)

df['undiffed_1'] = df['diff_1'] + df['MedianIncome']
df['diff_2'] = df['diff_2'] + df['diff_1']
df['diff_2'] = df['diff_2'].shift(1)
df['undiffed_2'] = df['diff_2'] + df['MedianIncome']

df['undiffed_1'] = df['undiffed_1'].shift(1)
df['undiffed_2'] = df['undiffed_2'].shift(1)

df['passed_1'] = df['undiffed_1'] == df['MedianIncome']
df['passed_2'] = df['undiffed_2'] == df['MedianIncome']

df[['MedianIncome','diff_1','diff_2','MedianIncome','undiffed_1','undiffed_2','passed_1','passed_2']]

# %%
copy_for_undifferencing = ready_for_undiff.copy()
copy_for_undifferencing['diff_1'] = copy_for_undifferencing['diff_1'].shift(-1)
copy_for_undifferencing['diff_2'] = copy_for_undifferencing['diff_2'].shift(-2)

copy_for_undifferencing['undiffed_1'] = copy_for_undifferencing['diff_1'] + copy_for_undifferencing['MedianIncome']
copy_for_undifferencing['diff_2'] = copy_for_undifferencing['diff_2'] + copy_for_undifferencing['diff_1']
copy_for_undifferencing['diff_2'] = copy_for_undifferencing['diff_2'].shift(1)
copy_for_undifferencing['undiffed_2'] = copy_for_undifferencing['diff_2'] + copy_for_undifferencing['MedianIncome']

copy_for_undifferencing['undiffed_1'] = copy_for_undifferencing['undiffed_1'].shift(1)
copy_for_undifferencing['undiffed_2'] = copy_for_undifferencing['undiffed_2'].shift(1)

copy_for_undifferencing['passed_1'] = copy_for_undifferencing['undiffed_1'] == copy_for_undifferencing['MedianIncome']
copy_for_undifferencing['passed_2'] = copy_for_undifferencing['undiffed_2'] == copy_for_undifferencing['MedianIncome']

copy_for_undifferencing[['MedianIncome','diff_1','diff_2','MedianIncome','undiffed_1','undiffed_2','passed_1','passed_2']]

# %%
assert 1 == 2 # Don't run this one if we don't need to (90 minute run time)
prediction_dataframes = []
age_ranges = master_table.AgeGroup.unique().tolist()
age_ranges = [_ for _ in age_ranges if str(_) != 'nan']
all_fips = master_table.FIPS.unique().tolist()
total = len(all_fips) * len(age_ranges)

cntr = 0
for i, age_range in enumerate(age_ranges):
    for ii, target_fips in enumerate(all_fips):
        params = [target_fips, age_range]
        target = 'MedianIncome'
        try:
            graph_ready, export_ready = arm.dispatcher(master_table, target, params)
        except Exception as E:
            print(f'Failure: {E}, params: {params}')
            cntr += 1
            continue
        export_ready['AgeGroup'] = age_range
        prediction_dataframes.append(export_ready)
        cntr += 1
        print(f'{cntr} of {total} completed')

# %%
prediction_dataframes = []
all_fips = master_table.FIPS.unique().tolist()
total = len(all_fips)

cntr = 0
for i, target_fips in enumerate(all_fips):
    params = [target_fips]
    target = 'MedianHousePrice'
    try:
        graph_ready, export_ready = arm.dispatcher(master_table, target, params)
    except Exception as E:
        print(f'Failure: {E}, params: {params}')
        cntr += 1
        continue
    prediction_dataframes.append(export_ready)
    cntr += 1
    print(f'{cntr} of {total} completed')

# %%
target = 'MedianHousePrice'
arm.graph_final_results(graph_ready, target)

# %%
export_ready

# %%
main_df = pd.DataFrame()

for df in prediction_dataframes:
    main_df = pd.concat([main_df,df])
    
main_df

# %%
main_df.tail(50)

# %%
main_df.to_csv("PredictedHousePrices.csv", index = False)

# %%
starter = main_df.shape[0]
print(starter * .15)

# %%
import joblib

# %%
prediction_dataframes = []
age_ranges = master_table.AgeGroup.unique().tolist()
age_ranges = [_ for _ in age_ranges if str(_) != 'nan']
all_fips = master_table.FIPS.unique().tolist()
total = len(all_fips) * len(age_ranges)
params = [target_fips, age_range]
target = 'MedianIncome'
    
graph_ready, export_ready = arm.dispatcher(master_table, target, params)

# %%
graph_ready

# %% [raw]
# graph_ready

# %%
from pmdarima.arima import auto_arima
from pmdarima.arima import ADFTest
import inspect
from bs4 import BeautifulSoup

soup = inspect.getsource(auto_arima)
print(soup)

# %%
#Docs = https://alkaline-ml.com/pmdarima/modules/generated/pmdarima.arima.auto_arima.html
from pmdarima.arima import auto_arima
from pmdarima.arima import ADFTest

target_fips = '34005'
params = [target_fips, age_range]
params = [target_fips]
target = 'MedianHousePrice'

# %%
adf_test = ADFTest(alpha=0.05)
filtered_data = arm.filter_data(master_table, target, params)
adf_test.should_diff(filtered_data[target])

# %%
#filtered_data.index = filtered_data.index.astype('str')

from sklearn.model_selection import train_test_split
y_train, y_test = train_test_split(filtered_data[[target]].dropna(), train_size = .75, shuffle = False)

fig, ax = plt.subplots()

y_train.plot(ax=ax)
y_test.plot(ax=ax)
plt.show()

arima_model = auto_arima(
    #Data
    y_train, 
    #NonSeasonalComponents
    start_p=0, start_q=0, d=1, max_p=5, max_d=5, max_q=5, 
    #SeasonalComponents
    start_P=0, D=1, start_Q=0, max_P=5, max_D=5,
    max_Q=5, m=4, seasonal=True, trace=True, stepwise=False, n_fits = 100)

prediction = pd.DataFrame(arima_model.predict(n_periods=y_test.shape[0]), index = y_test.index)
prediction.columns = [target+"_Prediction"]


# y_train = y_train.reset_index()
# y_train.drop(columns = ['new_index'], inplace = True)
# new_df = pd.concat([y_train,prediction])
# new_df = new_df.reset_index(drop = True)

# %%
import seaborn as sns

# %%
fig, ax = plt.subplots(figsize = (12,5))
# y_train.plot(ax=ax)
# y_test.plot(ax=ax)
#new_df.plot(ax=ax)
ax = sns.lineplot(x = y_train.index, y = y_train.MedianHousePrice)
ax = sns.lineplot(x = y_test.index, y = y_test.MedianHousePrice)
ax = sns.lineplot(x = prediction.index, y = prediction.MedianHousePrice_Prediction)
# y_train.plot(ax = ax)
# y_test.plot(ax = ax)
# prediction.plot(ax = ax)
plt.show()

# %%
#Docs = https://alkaline-ml.com/pmdarima/modules/generated/pmdarima.arima.auto_arima.html
from pmdarima.arima import auto_arima
from pmdarima.arima import ADFTest

# Get your data into the state it needs to be in
filtered_data = ?

adf_test.should_diff(filtered_data['MedianIncome'])

#filtered_data.index = filtered_data.index.astype('str')

from sklearn.model_selection import train_test_split
y_train, y_test = train_test_split(filtered_data['MedianIncome'].dropna(), train_size = .75, shuffle = False)

# This plotting method was necessary because my data was indexed by time period
fig, ax = plt.subplots()
y_train.plot(ax=ax)
y_test.plot(ax=ax)
plt.show()

arima_model = auto_arima(
    #Data
    y_train, 
    #NonSeasonalComponents
    start_p=0, start_q=0, d=1, max_p=5, max_d=5, max_q=5, 
    #SeasonalComponents
    start_P=0, D=1, start_Q=0, max_P=5, max_D=5,
    max_Q=5, m=1, seasonal=False, trace=True, stepwise=False, n_fits = 100)

prediction = pd.DataFrame(arima_model.predict(n_periods=20, index = y_test.index))
prediction.columns = ['Predictions']
plt.plot(prediction)
